# %% [markdown]
# <a href="https://colab.research.google.com/github/hyeonahkiki/GJ_AI_Academy/blob/master/1%EC%A3%BC%EC%B0%A8%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 4가지 제품 및 서비스
# ### 1. 언어
# - Google의 sandglass
#
#   사용기술: 방대한 수준의 언어 빅데이터와 AI, 딥러닝
#
#   -- 최신 NMT, AI 알고리즘을 기반으로 하며 전문 번역기임에도 불구하고 사용이 쉽다
#
#
# - 트위그팜의 Heybunny
#
#   설명 : 이메일 번역서비스
#
#   사용 : 한글로 작성된 테스트 이메일을 보냈더니 10초도 안되어 영어로 번역된 이메일이 돌아왔다.
#
#   기술 : 이메일에서 많이 쓰는 표현 1만 2000개를 학습시킨 것이 자연스러운 번역의 핵심
#
#
# ### 2. 음성
# - 아마존의 Alexa
# - Google Home
# - 삼성의 Bixby
#
#   -- 삼성의 Bixby에 사용된기술
#     1. 딥러닝
#       사물이나 데이터를 분류해내는데 최적화된 기술로 컴퓨터에 입력된 수 많은 데이터에서 패턴을 발견해 답을 도출해내는 것
#       1.1 지도학습
#         컴퓨터에 먼저 정보를 가르쳐주고 학습된 결과를 바탕으로 그와 관련된 다른 데이터를 스스로 구별할 수 있도록 하는 기술
#
#     2. 데이터
#       많은 데이터들을 제공할 수록 더욱 정확한 판단과 결과를 제공할 수 있게 된다.
#
#     3. 자연 언어 처리시스템의 구조
#       => 문장을 쪼개서 이해하는 것
#       문장이 입력되면 단어별로 쪼개서 각 정보를 찾는다.
#       이런방식을 통해 여러 명령을 동시에 담고 있는 복잡한 문장 뿐만 아니라 문장의 전체적 맥락까지 파악할 수 있다.
#
#
# ### 3. 이미지
# - Google Photo 서비스
#
#   설명 : 분류와 검색기능을 가지고 있음
#   어떤 지역에서 찍은 사진을 찾고 싶거나, 특정인물을 검색하고 싶다면 구글포토가 만들어 놓은 사진첩을 통해 관련된 사진을 찾을 수 있다.
#
# - 질병을 예측하고 분석하는 의료서비스
#
#   설명 : CT검사 결과를 기반으로 학습한 이미지 분석엔진이 페 결절을 97% 정확도로 찾아내고, 또 영상 판독을 보조해주는 경우 의사의 판독 정확도는 20%가 향상되는 실험 결과
#
# - 아마존의 텍스트튜브스(TextTubes)
#
#   설명 : 이미지 속에서 휘어진 텍스르를 읽어내는 알고리즘 기술
#
#   사용된기술
#   - 사진 등 이미지에서 글자로 쓰인 부분을 추출해 문자로 식별하는 OCR(Optical Character Recognition 광학문자인식)
#
#   사용예시
#   - SSG닷컴 '쓱렌즈'
#
#     이미지 상품검색 : 일일이 입력하기 까다로운 모델번호나 브랜드명도 사진만 찍어두면 텍스트로 추출, 검색이 가능하다
#
#
# ### 4. 자율주행
# - 현대자동차와 기아자동차의 SSC-ML
#
#   - 설명 : 운전자의 주행성향에 맞는 부분 자율주행을 구현하는 기술
#
#   - 기술
#
#   1. 스마트크루즈 컨트롤 SCC은 앞차와의 거리를 일정하게 유지해 운전자가 설정한 속도로 자율주행을 해주는 기능으로 ADAS(첨단 운전자보조 시스템)의 주요기술 중 하나.
#
#   2. 독자 개발한 SCC-ML의 원리는 전방카메라, 레이더 등의 센서가 다양한 운전상황에서 발생되는 정보를 지속적으로 수집해 ADAS의 두뇌격인 제어컴퓨터로 보낸다. 제어컴퓨터는 입력된 정보로부터 운전자의 주행습관을 추출해 종합적인 주행성향을 파악.
